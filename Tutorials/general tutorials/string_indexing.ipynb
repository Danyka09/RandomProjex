# %%
# indexing = accessing elements of a sequence using [] (indexing operator)
#                     [start : end : step]

credit_number = "1234-5678-9012-3456"

# %%
print(credit_number[0]) # print the first index; so the first character in this string
# Out:
# 1

# %%
print(credit_number[0:4]) # print first four digits. last is exclusive so it prints index 0,1,2,3 but not 4 so no dash -
# Out:
# 1234

# %%
print(credit_number[5:]) # print everything starting from 5
# Out:
# 5678-9012-3456

# %%
print(credit_number[-1]) # can go negative if we want to go backwards so print last digit

# %%
print(credit_number[-4:-1]) # my own test. it prints from -4 to -1 but not -1 itself cause exclusive but 0 dont work either
# Out:
# 345

# %%
# okay you just dont write the other one cause it assumes till the end
print(credit_number[-4:])
# Out:
# 3456

# %%
print(credit_number[::2]) # steps, so it prints every second character
# Out:
# 13-6891-46

# %%
reversed_number = ""
x = 19
while x > 0:
    x -= 1
    number = credit_number[x]
    reversed_number += number

print(reversed_number)
# Out:
# 6543-2109-8765-4321

# %%
# okay so this is the proper way
# reversing a string
print(credit_number[::-1])
# Out:
# 6543-2109-8765-4321
