# %%
string_1 = "Good"
string_2 = "Morning"

new_string = string_1 + string_2
print(new_string)
# Out:
# GoodMorning

# %%
string_1 = "Good"
string_2 = "Night"

new_string = string_1 + " " + string_2
print(new_string)
# Out:
# Good Night

# %%
credit_number = "1234-5678-9012-3456"
reversed_number = ""
x = 19
while x > 0:
    x -= 1
    number = credit_number[x]
    reversed_number += number

print(reversed_number)

# %%
name_list = ["Dano", "Dev", "Magyar Peter"]
names_output = ", ".join(name_list) # you use .join with what you want to join the list with and list goes inside parameter ()
print(names_output)
# Out:
# Dano, Dev, Magyar Peter

# %%
s1 = "Good"
s2 = "Afternoon"
string = "{} {}".format(s1,s2) # using formatting
print(string)
# Out:
# Good Afternoon
